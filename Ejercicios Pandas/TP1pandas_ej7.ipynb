# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Ejercicio 7
#
# ¿Cuáles son las tres aplicaciones pagas con peor Rating? (⭐)

# %% [markdown]
# Voy a utilizar únicamente las columnas App (nombre de la aplicación), Rating y Type (si es paga o no). Los demás detalles sobre las aplicaciones no son útiles para este ejercicio.

# %%
apps_details = pd.read_csv('/content/drive/MyDrive/Organización de Datos/googleplaystore.csv', usecols=['App', 'Rating', 'Type'])

# %% [markdown]
# Hay apps que aparecen repetidas y una tiene rating mayor a 5 o NaN. No las tendré en cuenta, las repetidas no me dan ningún tipo de información distinta sobre el rating y las de rating inválido no aportan nada para lo que se busca.
#
# Hay apps que tienen Type NaN, pero más adelante me quedaré solo con las pagas así que no será necesario filtrarlas antes.

# %%
apps_details[apps_details.App == 'Coloring book moana'] #ejemplo de repetición de una app (no necesario resolución)
# Out:
#                       App  Rating  Type
# 1     Coloring book moana     3.9  Free
# 2033  Coloring book moana     3.9  Free

# %%
apps_details[apps_details.Rating.isna()].head(3) #ejemplo apps con rating NaN (no necesario resolución)
# Out:
#                            App  Rating  Type
# 23      Mcqueen Coloring pages     NaN  Free
# 113  Wrinkles and rejuvenation     NaN  Free
# 123     Manicure - nail design     NaN  Free

# %%
apps_details[apps_details.Rating > 5] #ejemplo app inválida (no necesario resolución)
# Out:
#                                            App  Rating Type
# 10472  Life Made WI-Fi Touchscreen Photo Frame    19.0    0

# %%
apps_details = apps_details.drop_duplicates(subset='App')
apps_details = apps_details[apps_details.Rating <= 5]

# %%
apps_details[apps_details.Type == 'Paid'].nsmallest(3,"Rating")
# Out:
#                                 App  Rating  Type
# 4127              Speech Therapy: F     1.0  Paid
# 5978  Truck Driving Test Class 3 BC     1.0  Paid
# 6948        Bitcoin BX Thailand PRO     1.7  Paid
